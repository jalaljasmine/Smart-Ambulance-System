# %%
import pandas as pd

# Load datasets
accidents = pd.read_csv('../datasets/accidents.csv')
traffic = pd.read_csv('../datasets/traffic.csv')
hospitals = pd.read_csv('../datasets/hospitals.csv')

print('Accidents missing values before cleaning:')
print(accidents.isnull().sum()[accidents.isnull().sum() > 0])

# Remove duplicates
accidents = accidents.drop_duplicates()
print('\nAccidents shape after removing duplicates:', accidents.shape)
# Out:
# Accidents missing values before cleaning:
# Educational_level           741
# Vehicle_driver_relation     579
# Driving_experience          829
# Type_of_vehicle             950
# Owner_of_vehicle            482
# Service_year_of_vehicle    3928
# Defect_of_vehicle          4427
# Area_accident_occured       239
# Lanes_or_Medians            385
# Road_allignment             142
# Types_of_Junction           887
# Road_surface_type           172
# Type_of_collision           155
# Vehicle_movement            308
# Work_of_casuality          3198
# Fitness_of_casuality       2635
# dtype: int64
#
# Accidents shape after removing duplicates: (12316, 32)
