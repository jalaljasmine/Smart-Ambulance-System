# %%
import pandas as pd
import sys
sys.path.append('..')
from models.hospital_score import recommend_hospital

# Load hospital dataset
df = pd.read_csv('../datasets/hospitals.csv')
df.head(10)
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.9.0 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\ASUS\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator RandomForestClassifier from version 1.9.0 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
#                            Hospital  Latitude  Longitude  ICU_Beds  \
# 0       Government General Hospital   16.5062    80.6480       120
# 1                      NRI Hospital   16.5415    80.5150        90
# 2                   Andhra Hospital   16.5148    80.6400        60
# 3                   Ramesh Hospital   16.5068    80.6488        70
# 4                  Sentini Hospital   16.4895    80.6898        50
# 5       Manipal Hospital Vijayawada   16.5200    80.6300       100
# 6          Care Hospital Vijayawada   16.5105    80.6355        85
# 7  Vijaya Super Speciality Hospital   16.5155    80.6200        55
# 8     Sai Super Speciality Hospital   16.5035    80.6505        40
# 9                  Praveen Hospital   16.4998    80.6408        45
#
#   Trauma_Center  Emergency_Staff
# 0           Yes               80
# 1           Yes               70
# 2           Yes               50
# 3           Yes               60
# 4            No               40
# 5           Yes               75
# 6           Yes               65
# 7           Yes               45
# 8            No               35
# 9            No               30

# %%
for severity in ['Slight Injury', 'Serious Injury', 'Fatal Injury']:
    best = recommend_hospital(severity)
    print(f'=== {severity} ===')
    print(f'Top Recommended: {best["Hospital"]} (Score: {best["Score"]})')
    print()
# Out:
# === Slight Injury ===
# Top Recommended: Government General Hospital (Score: 50.0)
#
# === Serious Injury ===
# Top Recommended: Government General Hospital (Score: 100.0)
#
# === Fatal Injury ===
# Top Recommended: Government General Hospital (Score: 140.0)
